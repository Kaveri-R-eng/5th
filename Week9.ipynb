# %% [markdown]
# # 55. K-means [ using Mall Customers Data]

# %%
import pandas as p
import matplotlib.pyplot as m
import os
os.environ["OMP_NUM_THREADS"] = "1"
import warnings
warnings.filterwarnings("ignore", message="KMeans is known to have a memory leak")


from sklearn.cluster import KMeans

# Read the dataset
da = p.read_csv("D:\\csss\\Mall_Customers.csv")
x = da.iloc[:, [3, 4]].values

# Elbow Method to determine the optimal number of clusters
li = []
for i in range(1, 11):
    mod = KMeans(n_clusters=i, init='k-means++', random_state=42, n_init=10)
    mod.fit(x)
    li.append(mod.inertia_)

# Plotting the Elbow graph
m.plot(range(1, 11), li)
m.title("Elbow Method")
m.xlabel('Number of Clusters')
m.ylabel('Inertia')
m.show()

# Applying KMeans clustering with 5 clusters
from sklearn.cluster import MiniBatchKMeans

# Use MiniBatchKMeans instead of KMeans
mod = MiniBatchKMeans(n_clusters=5, init='k-means++', random_state=42, batch_size=100)

# Fit and predict
y_pred = mod.fit_predict(x)

# Continue with your plotting...

#mod = KMeans(n_clusters=5, init='k-means++', random_state=42, n_init=10)


# Plotting the clusters
m.scatter(x[y_pred == 0, 0], x[y_pred == 0, 1], s=100, c='blue', label='Cluster 1')
m.scatter(x[y_pred == 1, 0], x[y_pred == 1, 1], s=100, c='green', label='Cluster 2')
m.scatter(x[y_pred == 2, 0], x[y_pred == 2, 1], s=100, c='lime', label='Cluster 3')
m.scatter(x[y_pred == 3, 0], x[y_pred == 3, 1], s=100, c='red', label='Cluster 4')
m.scatter(x[y_pred == 4, 0], x[y_pred == 4, 1], s=100, c='black', label='Cluster 5')

# Plotting the centroids
m.scatter(mod.cluster_centers_[:, 0], mod.cluster_centers_[:, 1], s=300, c='yellow', label='Centroids')

# Final plot settings
m.title("Clusters of Customers")
m.xlabel("Annual Income (k$)")
m.ylabel("Spending Score (1-100)")
m.legend()
m.show()

# %% [markdown]
# # 56. Dimensionality Reduction [PCA] using iris Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
from sklearn import datasets 
from sklearn.decomposition import PCA
iris=datasets.load_iris()
x=iris.data
y=iris.target
print(x.shape) 
print(y.shape)
pca=PCA(n_components=2) 
pca.fit(x)
print(pca.components_)
x=pca.transform(x) 
print(x.shape) 
plt.scatter (x[:,0],x[:,1],c=y)
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
x_train, x_test,y_train,y_test=train_test_split(x,y,test_size=0.2) 
res=DecisionTreeClassifier() 
res.fit(x_train,y_train)
y_predict=res.predict(x_test) 
print(accuracy_score (y_test,y_predict))
# Out:
# (150, 4)
# (150,)
# [[ 0.36138659 -0.08452251  0.85667061  0.3582892 ]
#  [ 0.65658877  0.73016143 -0.17337266 -0.07548102]]
# (150, 2)
# 0.9666666666666667
