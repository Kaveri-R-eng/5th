# %% [markdown]
# # 59. Tokenization [Sentence & Word]

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize


# Open the file and read the content
with open("D:\\csss\\da.txt", "r") as f:
    text = f.read()

# Print the text
print(text)

# Tokenize the text into sentences
sent = sent_tokenize(text)
print("Number of sentences:", len(sent))
for i in range(len(sent)):
    print("\nSentence:", i + 1, "\n", sent[i])

# Tokenize the text into words
w = word_tokenize(text)
print("\nTotal Words:", len(w))
print(w)
# Out:
# Smartphones have become an essential part of our daily lives, offering communication, entertainment, and productivity all in one device. The rapid advancements in smartphone technology have led to features like facial recognition, high-resolution cameras, and 4G connectivity.
#
# Number of sentences: 2
#
# Sentence: 1
#  Smartphones have become an essential part of our daily lives, offering communication, entertainment, and productivity all in one device.
#
# Sentence: 2
#  The rapid advancements in smartphone technology have led to features like facial recognition, high-resolution cameras, and 4G connectivity.
#
# Total Words: 44
# ...

# %% [markdown]
# # 60.N-Grams

# %%
from nltk.util import ngrams
from nltk.tokenize import word_tokenize
f=open("D:\\csss\\da.txt")
text=f.read()
w=word_tokenize(text)
print("Bi-Grams:\n\n",list(ngrams(w,2)))
print("\n\nTri-Grams:\n\n",list(ngrams(w,3)))
# Out:
# Bi-Grams:
#
#  [('Smartphones', 'have'), ('have', 'become'), ('become', 'an'), ('an', 'essential'), ('essential', 'part'), ('part', 'of'), ('of', 'our'), ('our', 'daily'), ('daily', 'lives'), ('lives', ','), (',', 'offering'), ('offering', 'communication'), ('communication', ','), (',', 'entertainment'), ('entertainment', ','), (',', 'and'), ('and', 'productivity'), ('productivity', 'all'), ('all', 'in'), ('in', 'one'), ('one', 'device'), ('device', '.'), ('.', 'The'), ('The', 'rapid'), ('rapid', 'advancements'), ('advancements', 'in'), ('in', 'smartphone'), ('smartphone', 'technology'), ('technology', 'have'), ('have', 'led'), ('led', 'to'), ('to', 'features'), ('features', 'like'), ('like', 'facial'), ('facial', 'recognition'), ('recognition', ','), (',', 'high-resolution'), ('high-resolution', 'cameras'), ('cameras', ','), (',', 'and'), ('and', '4G'), ('4G', 'connectivity'), ('connectivity', '.')]
#
#
# Tri-Grams:
#
# ...

# %% [markdown]
# # 61. Frequency Distribution of Words

# %%
import pandas as p
import matplotlib.pyplot as m
from nltk.probability import FreqDist
freq=FreqDist(w)
print("Count of and word:",freq['and'])
freq=p.Series(dict(freq))
m.figure(figsize=(7,3))
freq.plot(kind='bar')
m.show()
# Out:
# Count of and word: 2

# %% [markdown]
# # 62. Removing Stop-words.

# %%
import nltk
import matplotlib.pyplot as m
import pandas as p
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
nltk.download('stopwords')#


# Assuming 'text' contains the content of the file you're analyzing
# Tokenize the text into words
w = word_tokenize(text)
print("Before Removal of Stopwords words count:", len(w))

# Load English stopwords
stop_w = nltk.corpus.stopwords.words('english')

# Remove stopwords
removed_stopw = [i for i in w if i.lower() not in stop_w]
print("\nAfter Removal of StopWords:", len(removed_stopw))

# Calculate word frequency distribution
freq = FreqDist(removed_stopw)

# Convert frequency distribution to pandas series
freq_series = p.Series(dict(freq))

# Plot the frequency distribution
m.figure(figsize=(8, 4))
freq_series.plot(kind='bar')
m.show()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rkave\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Before Removal of Stopwords words count: 44
#
# After Removal of StopWords: 32

# %% [markdown]
# # 63. Word-cloud

# %%
! pip install WordCloud

# %%
import numpy as np
from PIL import Image
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Load the background image
butter_image = np.array(Image.open('"D:\\csss\\kp.txt'))

# Create a list of words for the word cloud
text = '''
butter margarine spread dairy smooth creamy unsalted salted churn rich flavor cooking baking
melted toast pancakes buttercream frosting ghee whipped fat oil golden yellow food
'''

# Generate the word cloud
wordcloud = WordCloud(
    background_color="white",
    mask=butter_image,  # Use the butter image as the mask
    contour_width=3,    # Outline the shape
    contour_color='gold', # Color for the contour
    colormap='YlOrBr',  # Color map for butter tones
    max_words=200,
    width=800,
    height=800,
    random_state=42
).generate(text)

# Display the word cloud
plt.figure(figsize=(8, 8))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[24], line 7
#       4 import matplotlib.pyplot as plt
#       6 # Load the background image
# ----> 7 butter_image = np.array(Image.open('"D:\\csss\\kp.txt'))
#       9 # Create a list of words for the word cloud
#      10 text = '''
#      11 butter margarine spread dairy smooth creamy unsalted salted churn rich flavor cooking baking
#      12 melted toast pancakes buttercream frosting ghee whipped fat oil golden yellow food
#      13 '''
#
# File ~\anaconda3\Lib\site-packages\PIL\Image.py:3277, in open(fp, mode, formats)
#    3274     filename = os.path.realpath(os.fspath(fp))
#    3276 if filename:
# -> 3277     fp = builtins.open(filename, "rb")
#    3278     exclusive_fp = True
#    3280 try:
#
# OSError: [Errno 22] Invalid argument: 'C:\\Users\\rkave\\OneDrive\\Desktop\\5th\\"D:\\csss\\kp.txt'

# %%
import matplotlib.pyplot as m
from wordcloud import WordCloud, STOPWORDS
import numpy as np
from PIL import Image

# Load your text data
f = open("C:\\Users\\HP\\Downloads\\da.txt")
text = f.read()

# Load the butterfly mask image
butterfly_mask = np.array(Image.open("C:\\Users\\HP\\Pictures\\Butterfly.jpeg"))

# Create a set of stopwords
stop_w = set(STOPWORDS)

# Create the WordCloud object with the butterfly mask
wc = WordCloud(width=800, height=800,
               background_color='white',  # Set background to white for light color
               colormap='Pastel1',  # Use a light color colormap
               stopwords=stop_w,
               min_font_size=10,
               mask=butterfly_mask,  # Apply the butterfly mask
               contour_color='black',  # Optional: Change contour to black for contrast
               contour_width=1.5).generate(text)


# Plotting the WordCloud
m.figure(figsize=(8, 8), facecolor=None)
m.imshow(wc, interpolation='bilinear')
m.axis('off')
m.tight_layout(pad=0)
m.show()

# %% [markdown]
# # 64. Stemming & Lemmatization

# %%
import re
from nltk.tokenize import word_tokenize
f=open("D:\\csss\\da.txt")
text=f.read()
text=text.lower()
text=re.sub('[^A-Za-z0-9]+',' ',text)
text=re.sub("\'S'*\'d'\'S'*","",text).strip()
print(text)
w=word_tokenize(text,preserve_line=True)
from nltk.stem import PorterStemmer
ps=PorterStemmer()
ps_st=[ps.stem(i) for i in w]
print("\nStemming:\n\n",ps_st)
from nltk import WordNetLemmatizer
wnl=WordNetLemmatizer()
lema=[wnl.lemmatize(u) for u in w]
print("\n Lemmatization:\n\n",lema)
# Out:
# smartphones have become an essential part of our daily lives offering communication entertainment and productivity all in one device the rapid advancements in smartphone technology have led to features like facial recognition high resolution cameras and 4g connectivity
#
# Stemming:
#
#  ['smartphon', 'have', 'becom', 'an', 'essenti', 'part', 'of', 'our', 'daili', 'live', 'offer', 'commun', 'entertain', 'and', 'product', 'all', 'in', 'one', 'devic', 'the', 'rapid', 'advanc', 'in', 'smartphon', 'technolog', 'have', 'led', 'to', 'featur', 'like', 'facial', 'recognit', 'high', 'resolut', 'camera', 'and', '4g', 'connect']
#
#  Lemmatization:
#
# ...

# %%
# Build the LSTM model
model = Sequential()

# Embedding layer (without input_length)
model.add(Embedding(input_dim=max_words, output_dim=128))

# LSTM layer
model.add(LSTM(units=128, dropout=0.2, recurrent_dropout=0.2))

# Fully connected layer
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=5, batch_size=32, validation_split=0.2)

# Evaluate the model on test data
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy}")

# Predict sentiment for new reviews
new_reviews = ["I love this product", "Worst purchase ever"]
sequences = tokenizer.texts_to_sequences(new_reviews)
X_new = pad_sequences(sequences, maxlen=max_len)
predictions = model.predict(X_new)

# Output the predicted sentiments
for i, review in enumerate(new_reviews):
    sentiment = "positive" if predictions[i] > 0.5 else "negative"
    print(f"Review: {review}, Sentiment: {sentiment}")
